# %%
import pandas as pd
import numpy as np
import os as os

terror=pd.read_csv('terror.csv',encoding='latin')
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (4,61,62,66,116,117,123) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Q.1)How many attacks happened in India?

q1=terror[terror.country_txt=='India'].country_txt.count()
q1
# Out:
# 9940

# %%
#Q.2)How many attacks happened in India and upto 3 people were killed? 

q2=terror[(terror.country_txt=='India') & (terror.nkill<=3)].country_txt.count()
q2
# Out:
# 8362

# %%
3#Extract the city and summary for attacks above

q3=terror[(terror.country_txt=='India') & (terror.nkill<=3)][['city','summary']]
q3.head()
# Out:
#            city summary
# 1185  New Delhi     NaN
# 3780  New Delhi     NaN
# 5251     Bombay     NaN
# 7266     Imphal     NaN
# 8609    Unknown     NaN

# %%
#Q.4)In a single terror incident in India, find out top 5 cities by number killed

q4=terror[(terror.country_txt=='India')].sort_values(by="nkill",ascending=False)[['city','nkill']]
q4.head()
# Out:
#                      city  nkill
# 81000              Mumbai  188.0
# 96598             Jhargam  115.0
# 54339              Bombay  115.0
# 95860  Dantewada district   82.0
# 56837            Banabari   70.0

# %%
#Q.5)In a single terror incident in India, find out top 5 cities by number killed and wounded 

q5=terror[(terror.country_txt=='India')].sort_values(by='nwound',ascending=False)[['city','nkill','nwound']]
q5.head()
# Out:
#             city  nkill  nwound
# 81000     Mumbai  188.0   817.0
# 89128     Dispur   37.0   235.0
# 30378    Chennai   32.0   200.0
# 79045  New Delhi   55.0   155.0
# 75769     Mumbai   52.0   150.0

# %%
#How many attacks were successful that were suicide attacks?

q6=terror[(terror.weapsubtype1_txt=='Suicide (carried bodily by human being)') & (terror.success==1)].success.count()
q6
# Out:
# 1930

# %%
#label all the incidents where the number killed was more than 5 as severe.

terror['severity']=['severe' if i>5 else 'not severe'  for i in terror.nkill]

terror['severity']
# Out:
# 0         not severe
# 1         not severe
# 2         not severe
# 3         not severe
# 4         not severe
# 5         not severe
# 6         not severe
# 7         not severe
# 8         not severe
# 9         not severe
# 10        not severe
# 11        not severe
# 12        not severe
# 13        not severe
# 14        not severe
# 15        not severe
# 16        not severe
# 17        not severe
# 18        not severe
# 19        not severe
# 20        not severe
# 21        not severe
# 22        not severe
# 23        not severe
# 24        not severe
# 25        not severe
# 26        not severe
# 27        not severe
# 28        not severe
# 29        not severe
#              ...
# 156742    not severe
# 156743    not severe
# 156744    not severe
# 156745    not severe
# 156746    not severe
# 156747    not severe
# 156748    not severe
# 156749    not severe
# 156750    not severe
# 156751    not severe
# 156752    not severe
# 156753    not severe
# 156754    not severe
# 156755    not severe
# 156756    not severe
# 156757    not severe
# 156758    not severe
# 156759    not severe
# 156760    not severe
# 156761    not severe
# 156762        severe
# 156763    not severe
# 156764    not severe
# 156765    not severe
# 156766    not severe
# 156767    not severe
# 156768    not severe
# 156769    not severe
# 156770    not severe
# 156771    not severe
# Name: severity, Length: 156772, dtype: object

# %%
#8write a function to label an incident that was both successful and suicidal

def fun(x):
    j=["Success" if (x.iloc[i].suicide==1 and x.iloc[i].success==1) else "Failure" for i in list(range(0,len(x)))]
    return j

fun(terror)
# Out:
# ['Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  'Failure',
#  ...]

# %%
#Q.9)	Create a new category representing if the incident occured in Afghanistan, 
#Pakistan or India as one level of the category and all the other countries as another level

terror['levels']=['Asia' if (terror.iloc[i].country_txt=='Afghanistan' or terror.iloc[i].country_txt=='Pakistan' or terror.iloc[i].country_txt=='India') else 'Row' for i in list(range(0,len(terror.country_txt))) ]
    
terror['levels'].head()
# Out:
# 0    Row
# 1    Row
# 2    Row
# 3    Row
# 4    Row
# Name: levels, dtype: object

# %%
#Q.10)	How many incidents happened in Af-Pak-India vs ROW?

print(terror[terror.levels=="Asia"].levels.count()*100/ terror[terror.levels=="Row"].levels.count())
# Out:
# 26.048852654091693

# %%
#Q.11)	List the number of suicides attacks and average kills by 
#Af-Pak-India vs ROW. Rename columns in the output as Average_Kills and Number_Incidents.

terror[terror.suicide==1].groupby('levels')[['nkill']].agg(['count','mean']).rename(columns ={'count': 'Number_Incidents','mean': 'Average_Kills'})
# Out:
#                   nkill
#        Number_Incidents Average_Kills
# levels
# Asia               1456      8.127404
# Row                3250     11.511403
